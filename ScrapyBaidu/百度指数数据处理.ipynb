# %% [markdown]
# ### 引包

# %%
import numpy as np
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# ### 连接数据库

# %%
con = create_engine('mysql+pymysql://root:Tianhao0311@cdb-8b46fhc0.bj.tencentcdb.com:10204/baiduindexdb')

# %% [markdown]
# ### 读取省份ID和城市ID

# %%
prov_id = pd.read_sql_table("province_id",con)
city_id = pd.read_sql_table("city_id",con)

# %%
time_range = ("2019-01-20", "2019-01-21")
time_1 = time_range[0]
time_2 = time_range[1]

# %%
time_1
# Out:
# '2019-01-20'

# %%
time_2
# Out:
# '2019-01-21'

# %% [markdown]
# ### 读取百度指数

# %%
sql = "SELECT * FROM baidu_index_1125 WHERE DATE >= '{}' AND DATE <= '{}'".format(time_1,time_2)
index = pd.read_sql(sql,con)

# %%
index.shape
# Out:
# (2, 4)

# %%
index.replace(to_replace=r'^\s*$',value=np.nan,regex=True,inplace=True)
index = index.dropna()

# %%
index
# Out:
#    id keyword _index        date
# 0  20    南京银行   1747  2019-01-20
# 1  21    南京银行   2394  2019-01-21

# %% [markdown]
# ### 字段处理

# %%
index['date'] = pd.to_datetime(index['date']).dt.strftime('%Y-%m')
index['keyword'] = index['keyword'].apply(lambda x: x.strip(' \r\n\t').upper())
index['_index'] = index['_index'].astype(int)

# %%
new_index_mean = index.groupby(['keyword'])['_index'].sum() # 单位为月份

# %%
new_index_mean = new_index_mean.reset_index()

# %%
new_index_mean
# Out:
#   keyword  _index
# 0    南京银行    4141

# %% [markdown]
# ### 读取省份数据

# %%
sql = "SELECT * FROM province_index WHERE DATE ='{}|{}'".format(time_1,time_2)
prov_index = pd.read_sql(sql,con)

# %%
prov_index.shape
# Out:
# (33, 5)

# %%
prov_index = prov_index.drop_duplicates(['keyword','prov','prov_index','date'])

# %% [markdown]
# #### 字段处理

# %%
prov_index['date'] = prov_index['date'].apply(lambda x :x.split("|")[0]) # 取出日期前半部分
prov_index['date']=pd.to_datetime(prov_index['date']) # 格式化日期
prov_index['prov_index'] = prov_index['prov_index'].astype(int)
prov_index['date'] = prov_index['date'].dt.strftime('%Y-%m') # 将日期转换成月份
prov_index['keyword'] = prov_index['keyword'].apply(lambda x: x.strip(' \r\n\t').upper())

# %% [markdown]
# #### 计算省份占比

# %%
prov_index_sum = prov_index.groupby(['keyword'])["prov_index"].sum().reset_index()

# %%
prov_percent = pd.merge(prov_index,prov_index_sum,on=['keyword'])

# %%
prov_percent["pct"] = prov_percent["prov_index_x"]/prov_percent["prov_index_y"]

# %%
prov_percent.head()
# Out:
#     id keyword  prov  prov_index_x     date  prov_index_y       pct
# 0   94    南京银行   916          1000  2019-01          2018  0.495540
# 1  119    南京银行   910           203  2019-01          2018  0.100595
# 2  144    南京银行   911           175  2019-01          2018  0.086720
# 3  169    南京银行   917            95  2019-01          2018  0.047076
# 4  194    南京银行   913            85  2019-01          2018  0.042121

# %% [markdown]
# #### 合并百度指数

# %%
prov_index_final = pd.merge(prov_percent,new_index_mean,on=["keyword"])

# %%
prov_index_final
# Out:
#      id keyword  prov  prov_index_x     date  prov_index_y       pct  _index
# 0    94    南京银行   916          1000  2019-01          2018  0.495540    4141
# 1   119    南京银行   910           203  2019-01          2018  0.100595    4141
# 2   144    南京银行   911           175  2019-01          2018  0.086720    4141
# 3   169    南京银行   917            95  2019-01          2018  0.047076    4141
# 19   569    南京银行   905            11  2019-01          2018  0.005451    4141
# 20   594    南京银行   904            11  2019-01          2018  0.005451    4141
# 21   619    南京银行   915            10  2019-01          2018  0.004955    4141
# 22   644    南京银行   930            10  2019-01          2018  0.004955    4141
# 23   669    南京银行   922             9  2019-01          2018  0.004460    4141
# 24   694    南京银行   902             9  2019-01          2018  0.004460    4141
# 25   719    南京银行   921             7  2019-01          2018  0.003469    4141
# 26   743    南京银行   926             7  2019-01          2018  0.003469    4141
# 27   764    南京银行   933             6  2019-01          2018  0.002973    4141
# 28   784    南京银行   925             4  2019-01          2018  0.001982    4141
# 29   798    南京银行   919             3  2019-01          2018  0.001487    4141
# 30   809    南京银行   918             1  2019-01          2018  0.000496    4141
# 31   816    南京银行   931             1  2019-01          2018  0.000496    4141
# 32   820    南京银行   932             0  2019-01          2018  0.000000    4141
#
#     real_prov_index  id_y name
# 0       2052.031715   916   江苏
# 1        416.562438   910   上海
# 2        359.105550   911   北京
# 3        194.943013   917   浙江
# 4        174.422696   913   广东
# 5        112.861744   928   安徽
# 6         84.133300   927   河南
# 7         84.133300   901   山东
# 8         63.612983   907   辽宁
# 9         57.456888   908   湖南
# 10        57.456888   920   河北
# 11        55.404856   914   四川
# 12        51.300793   909   福建
# 13        49.248761   906   湖北
# 14        36.936571   929   山西
# 15        28.728444   924   陕西
# 16        28.728444   903   江西
# 17        26.676412   912   广西
# 18        24.624381   923   天津
# 19        22.572349   905  内蒙古
# 20        22.572349   904   重庆
# 21        20.520317   915   云南
# 22        20.520317   930   海南
# 23        18.468285   922   吉林
# 24        18.468285   902   贵州
# 25        14.364222   921  黑龙江
# 26        14.364222   926   新疆
# 27        12.312190   933   香港
# 28         8.208127   925   甘肃
# 29         6.156095   919   宁夏
# 30         2.052032   918   青海
# 31         2.052032   931   台湾
# 32         0.000000   932   西藏

# %%
prov_name = "prov_{}-{}.xlsx".format(time_1,time_2)
prov_index_final.to_excel(prov_name)

# %% [markdown]
# ### 城市分布数据

# %% [markdown]
# #### 读取城市数据

# %%
sql = "SELECT * FROM city_index WHERE DATE ='{}|{}'".format(time_1,time_2)
city_index = pd.read_sql(sql,con) 
prov_index_final.keyword = prov_index_final.keyword.str.lower()

# %%
city_index['date'] = city_index['date'].apply(lambda x :x.split("|")[0])
city_index['date']=pd.to_datetime(city_index['date'])
city_index['date'] = city_index['date'].dt.strftime('%Y-%m') # 将日期转换成月份

# %%
city_index_sum = city_index.groupby(['keyword','prov'])['city_index'].sum().reset_index()

# %%
city_index2 = pd.merge(city_index,city_index_sum,on=("keyword","prov"))
city_index2['pct'] = city_index2['city_index_x']/city_index2['city_index_y']
city_index_final = pd.merge(city_index2,prov_index_final,on=('keyword','prov','date'))

# %%
city_index_final
# Out:
#        id keyword  city  city_index_x  prov     date  city_index_y     pct_x  \
# 0      87    南京银行     1          1000   901  2019-01          4359  0.229410
# 1     112    南京银行    77           789   901  2019-01          4359  0.181005
# 2     139    南京银行    79           368   901  2019-01          4359  0.084423
# 3     167    南京银行    76           315   901  2019-01          4359  0.072264
# 4     196    南京银行   366           263   901  2019-01          4359  0.060335
# ..    ...     ...   ...           ...   ...      ...           ...       ...
# 253  6206    南京银行   242           111   930  2019-01          2443  0.045436
# 254  6209    南京银行   675           111   930  2019-01          2443  0.045436
# 255  6212    南京银行   670           111   930  2019-01          2443  0.045436
# 256  6247    南京银行   655          1000   932  2019-01          1000  1.000000
# 257  6277    南京银行   663          1000   933  2019-01          1000  1.000000
#
#      id_x  prov_index_x  prov_index_y     pct_y  _index  real_prov_index  \
# 0     269            41          2018  0.020317    4141        84.133300
# 1     269            41          2018  0.020317    4141        84.133300
# 2     269            41          2018  0.020317    4141        84.133300
# 3     269            41          2018  0.020317    4141        84.133300
# 4     269            41          2018  0.020317    4141        84.133300
# ..    ...           ...           ...       ...     ...              ...
# 253   644            10          2018  0.004955    4141        20.520317
# 254   644            10          2018  0.004955    4141        20.520317
# 255   644            10          2018  0.004955    4141        20.520317
# 256   820             0          2018  0.000000    4141         0.000000
# 257   764             6          2018  0.002973    4141        12.312190
#
#      id_y name
# 0     901   山东
# 1     901   山东
# 2     901   山东
# 3     901   山东
# 4     901   山东
# ..    ...  ...
# 253   930   海南
# 254   930   海南
# 255   930   海南
# 256   932   西藏
# 257   933   香港
#
# [258 rows x 16 columns]

# %%
city_index_final["real_city_index"] = city_index_final['pct_x']*city_index_final['real_prov_index']

# %%
city_index_final = pd.merge(city_index_final,city_id,left_on='city',right_on="id")

# %%
city_name = "city_{}-{}.xlsx".format(time_1,time_2)
city_index_final.to_excel(city_name)

# %%
city_index_final
# Out:
#      id_x keyword  city  city_index_x  prov     date  city_index_y     pct_x  \
# 0      87    南京银行     1          1000   901  2019-01          4359  0.229410
# 1     112    南京银行    77           789   901  2019-01          4359  0.181005
# 2     139    南京银行    79           368   901  2019-01          4359  0.084423
# 3     167    南京银行    76           315   901  2019-01          4359  0.072264
# 4     196    南京银行   366           263   901  2019-01          4359  0.060335
# ..    ...     ...   ...           ...   ...      ...           ...       ...
# 245  6203    南京银行   683           111   930  2019-01          2443  0.045436
# 246  6206    南京银行   242           111   930  2019-01          2443  0.045436
# 247  6209    南京银行   675           111   930  2019-01          2443  0.045436
# 248  6212    南京银行   670           111   930  2019-01          2443  0.045436
# 249  6247    南京银行   655          1000   932  2019-01          1000  1.000000
#
#      id_x  prov_index_x  prov_index_y     pct_y  _index  real_prov_index  \
# 0     269            41          2018  0.020317    4141        84.133300
# 1     269            41          2018  0.020317    4141        84.133300
# 2     269            41          2018  0.020317    4141        84.133300
# 3     269            41          2018  0.020317    4141        84.133300
# 4     269            41          2018  0.020317    4141        84.133300
# ..    ...           ...           ...       ...     ...              ...
# 245   644            10          2018  0.004955    4141        20.520317
# 246   644            10          2018  0.004955    4141        20.520317
# 247   644            10          2018  0.004955    4141        20.520317
# 248   644            10          2018  0.004955    4141        20.520317
# 249   820             0          2018  0.000000    4141         0.000000
#
#      id_y name_x  real_city_index  id_y name_y
# 0     901     山东        19.301055     1     济南
# 1     901     山东        15.228533    77     青岛
# 2     901     山东         7.102788    79     临沂
# 3     901     山东         6.079832    76     滨州
# 4     901     山东         5.076178   366     日照
# ..    ...    ...              ...   ...    ...
# 245   930     海南         0.932360   683     昌江
# 246   930     海南         0.932360   242     琼海
# 247   930     海南         0.932360   675     澄迈
# 248   930     海南         0.932360   670     文昌
# 249   932     西藏         0.000000   655     那曲
#
# [250 rows x 19 columns]
